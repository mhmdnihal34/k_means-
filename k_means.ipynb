# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
image=cv2.imread(r"/content/7534a63e-f340-4d59-bc4b-87e08d6b3d48.jpeg")
image_rgb=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
pixel=image_rgb.reshape((-1,3))
pixel=np.float32(pixel)
criteria=(cv2.TERM_CRITERIA_EPS+cv2.TERM_CRITERIA_MAX_ITER,100,0.85)
k=10
_,labels,centers = cv2.kmeans(pixel,k,None,criteria,5,cv2.KMEANS_PP_CENTERS)
centers = np.uint8(centers)
_,counts = np.unique(labels,return_counts=True)
fig, ax = plt.subplot(1, 2, figsize=(14,5))
segment_data = centers[labels.flatten()]
segment_image = segment_data.reshape((image_rgb.shape))
ax[0].imshow(segment_image)
ax[0].set_title("Segmented Image")
ax[0].axis('off')
sorted__indices = np.argsort(-counts)
sorted_colors = centers[sorted_indices]
sorted_counts = counts[sorted_indices]
fractions = sorted_counts/np.sum(sorted_counts)
ax[1].pie(fractions, colors=np.array(sorted_colors)/255,labels=[f'{i+1}'for i in range (k)],startangle=90,counterclock=False)
ax[1].set_title("Dominant Colors (pie chart)")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-024ff044c8da> in <cell line: 0>()
#      11 centers = np.uint8(centers)
#      12 _,counts = np.unique(labels,return_counts=True)
# ---> 13 fig, ax = plt.subplot(1, 2, figsize=(14,5))
#      14 segment_data = centers[labels.flatten()]
#      15 segment_image = segment_data.reshape((image_rgb.shape))
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1548
#    1549     # First, search for an existing subplot with a matching spec.
# -> 1550     key = SubplotSpec._from_subplot_args(fig, args)
#    1551
#    1552     for ax in fig.axes:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/gridspec.py in _from_subplot_args(figure, args)
#     574             rows, cols, num = args
#     575         else:
# --> 576             raise _api.nargs_error("subplot", takes="1 or 3", given=len(args))
#     577
#     578         gs = GridSpec._check_gridspec_exists(figure, rows, cols)
#
# TypeError: subplot() takes 1 or 3 positional arguments but 2 were given

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
image = cv2.imread(r"/content/7534a63e-f340-4d59-bc4b-87e08d6b3d48.jpeg")
image_rgb=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
pixel=image_rgb.reshape((-1,3))
pixel = np.float32(pixel)
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 100,0.85)
k=10
_,labels,centers = cv2.kmeans(pixel,k,None,criteria,5,cv2.KMEANS_PP_CENTERS)
centers = np.uint8(centers)
_,counts = np.unique(labels,return_counts=True)
fig, ax = plt.subplots(1, 2, figsize=(14,5))
segment_data = centers[labels.flatten()]
segment_image = segment_data.reshape((image_rgb.shape))
ax[0].imshow(segment_image)
ax[0].set_title("Segmented Image")
ax[0].axis('off')
sorted_indices = np.argsort(-counts)
sorted_colors = centers[sorted_indices]
sorted_counts = counts[sorted_indices]
fractions = sorted_counts/np.sum(sorted_counts)
ax[1].pie(fractions, colors=np.array(sorted_colors)/255,labels=[f'{i+1}'for i in range (k)],startangle=90,counterclock=False)
ax[1].set_title("Dominant Colors (pie chart)")
plt.tight_layout()
plt.show()

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-python) (2.0.2)
